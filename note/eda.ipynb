# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
edf = pd.read_parquet('../data/extract/')

# %%
edf.head(3)
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd    movieNm      openDt  \
# 0    1    1         0           OLD  20137048       국제시장  2014-12-17
# 1    2    2         1           OLD  20143642      테이큰 3  2015-01-01
# 2    3    3        -1           OLD  20149859  마다가스카의 펭귄  2014-12-31
#
#      salesAmt salesShare  salesInten  ...     salesAcc audiCnt audiInten  \
# 0  6129982500       47.3  2797599300  ...  47219550096  751754    275212
# 1  2644551100       20.4  1640018100  ...   3658460100  321653    177118
# 2  1687516200       13.0   672528400  ...   2736013000  212779     67641
#
#   audiChange  audiAcc scrnCnt showCnt   load_dt multiMovieYn repNationCd
# 0       57.8  6097431     941    4650  20150101            N         NaN
# 1      122.5   467280     614    2947  20150101            N         NaN
# 2       46.6   361669     594    1846  20150101            N         NaN
#
# [3 rows x 21 columns]

# %%
edf_grouped = edf.groupby('openDt').size().reset_index(name='count')

# %%
plt.plot(edf_grouped['openDt'], edf_grouped['count'])
plt.xlabel('open_dt')
plt.ylabel('cnt')
plt.title('open_dt cnt')
plt.xticks(edf_grouped['openDt'][::15], rotation=90)
plt.show()

# %%
edf[edf.openDt == '1971-07-31']
# Out:
#       rnum rank rankInten rankOldAndNew   movieCd  movieNm      openDt  \
# 11459   10   10         0           NEW  19880104  노틀담의 꼽추  1971-07-31
# 11497    8    8         2           OLD  19880104  노틀담의 꼽추  1971-07-31
# 11539   10   10        -2           OLD  19880104  노틀담의 꼽추  1971-07-31
#
#       salesAmt salesShare salesInten  ...  salesAcc audiCnt audiInten  \
# 11459   540000        1.0     540000  ...  17753000     270       270
# 11497   710000        0.8     170000  ...  18463000     355        85
# 11539   434000        0.5    -276000  ...  18897000     217      -138
#
#       audiChange audiAcc scrnCnt showCnt   load_dt multiMovieYn repNationCd
# 11459        100    8851       1       4  20151014            Y         NaN
# 11497       31.5    9206       1       4  20151015            Y         NaN
# 11539      -38.9    9423       1       4  20151016            Y         NaN
#
# [3 rows x 21 columns]
